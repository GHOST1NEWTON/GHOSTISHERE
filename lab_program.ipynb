# %% [markdown]
# <a href="https://colab.research.google.com/github/GHOST1NEWTON/GHOSTISHERE/blob/main/lab_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=56;
b=53456;
c=a=b;
print(c)
# Out:
# 53456

# %%
a="akash";
b="kelambakkam";
print(a+' '+b)
# Out:
# akash kelambakkam

# %%
x=("vadamapula")
type(x)
# Out:
# str

# %%
x=(343>34)
print(x)
# Out:
# True

# %%
g="rhgthwg4qhtgwegtiwgthtjhttgg"
len(g)
# Out:
# 28

# %%
h=input("name")
p=input("age")
print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0838744d68b1> in <module>()
# ----> 1 rkgmocikfmkfmdkmfpsfl
#       2 fsfgdgfgh
#       3 ddgf
#       4 g
#
# NameError: name 'rkgmocikfmkfmdkmfpsfl' is not defined

# %%
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')
 
sum = float(num1) + float(num2)
 

print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# Enter first number: 56
# Enter second number: 56
# The sum of 56 and 56 is 112.0

# %%
num = 1+2j

 
num_sqrt = c.math.sqrt(num)
print('The square root of {0} is {1:0.3f}+{2:0.3f}j'.format(num ,num_sqrt.real,num_sqrt
# Out:
#   File "<ipython-input-17-3fcdbe4a3a1d>", line 8
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
 a=input("enter the string \n")
 b=input("enter the other string \t")
 if (a == b):
   print("the string are equal")
 else:
   print(" the string are nor equal")
# Out:
# enter the string
# kaka
# enter the other string 	kaka
# the string are equal

# %%
a=445
b=222
a/b
# Out:
# 2.0045045045045047

# %%
a=77
b=888
a%b
# Out:
# 77

# %%
in

# %%
a=input('enter the number :')
b=input("enter the second no :")
sum=float(a)+float(b)
print(' the sum of{0} and {1} is{2}'.format(a,b,sum4))
# Out:
# enter the number :4.5
# enter the second no :5.4
#  the sum of4.5 and 5.4 is9.9

# %%
a=input("enter the lenth of the triangle :")
b=input("enter the breath of the triangle :")
c=0.5
area=(a*b)
total=area*c
print("the area of the triangle" ,total)
# Out:
# enter the lenth of the triangle :44
# enter the breath of the triangle :4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ec726af83a52> in <module>()
#       2 b=input("enter the breath of the triangle :")
#       3 c=0.5
# ----> 4 area=(a*b)
#       5 total=area*c
#       6 print("the area of the triangle" ,total)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a=5
b=4
temp=a
a=b
b=temp

print("the value of the a is {}".format(a))
print("the value of the b is {}".format(b))
# Out:
# the value of the a is 4
# the value of the b is 5

# %%
 a=5
 b=6
 c=7
 s=(a+b+c)/2
 area=(s*(s-a)*(s-b)*(s-c))**0.5
 print("the area of the triangle",float(area))
# Out:
# the area of the triangle 14.696938456699069

# %%
fruit=['orange','apple','grape','mango','banana']
game=('uncharted','spiderman','prototype','gta5')
cryptocoins={'b':'bitcoin',"sol":"solana","eth":"ethereum","bnb":"binance coin"}
char={'a','s','f','j'}
print(fruit
)
print(game)
print(cryptocoins ["sol"])
print(char)
# Out:
# ['orange', 'apple', 'grape', 'mango', 'banana']
# ('uncharted', 'spiderman', 'prototype', 'gta5')
# solana
# {'a', 's', 'f', 'j'}

# %%
a=eval(input("no"))
b=eval(input("second no"))
sum=a+b
print(sum
      )
# Out:
# no1+2
# second no3+1
# 7

# %%
a="virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*("
b=1000
a*b\n
# Out:
# 'virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$%^&*(virus$+============================$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ...

# %%
a="$$$$$$$$$$$$$$virus___|||||||\\\\\\\\||||||||||"
b=1000000
print(a*b)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
x=3
y=10
x//y
# Out:
# 0

# %%
print("Enter your choices")
print("press 1 for addition,2 for sub, 3 for multiple")
if (n==1)
# Out:
# Enter your choices
# press 1 for addition,2 for sub, 3 for multiple,4 for divide,5 for quit

# %%
num = 15
if num >= 0:
	if num == 0:
		print("Zero")
	else:
		print("Positive number")
else:
	print("Negative number")
# Out:
# Positive number

# %%
num = int(input("enter number"))
if num%2 == 0:
   if num%3 == 0:
      print ("Divisible by 3 and 2")
   else:
      print ("divisible by 2 not divisible by 3")
else:
   if num%3 == 0:
      print ("divisible by 3 not divisible by 2")
   else:
      print  ("not Divisible by 2 not divisible by 3")
# Out:
# enter number44
# divisible by 2 not divisible by 3

# %%
age = int(input(" Please Enter Your Age Here:  "))
if age < 18:
    print(" You are Minor ") 
    print(" You are not Eligible to Work ") 
else:
    if age >= 18 and age <= 60:
        print(" You are Eligible to Work ")
        print(" Please fill in your details and apply")
    else:
        print(" You are too old to work as per the Government rules")
        print(" Please Collect your pension!")
# Out:
#  Please Enter Your Age Here:  18
#  You are Eligible to Work
#  Please fill in your details and apply
